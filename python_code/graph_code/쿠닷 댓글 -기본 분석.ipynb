# %%
import pandas as pd
from datetime import datetime
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/쿠키닷컴/성지순례.csv", encoding="utf-8", parse_dates=['날짜'])
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21649 entries, 0 to 21648
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   닉네임     21649 non-null  object
#  1   댓글      21626 non-null  object
#  2   날짜      21649 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 507.5+ KB

# %%
df
# Out:
#                  닉네임                               댓글                  날짜
# 0      복숭아맛(163.180)               아참 운송료 미포함 가격 입니다. 2001-07-17 17:55:57
# 1         정추영(61.78)                         재미없스.... 2001-07-17 18:03:12
# 2         x(211.206)       야~ 참 재밋스신 분이시네요...한참 웃엇습니다 2001-07-17 18:13:45
# 3       ㅡ.ㅡ(211.107)          >>ㅑ~~~~~~~ 안사안사~~~~~~~~ 2001-07-17 18:57:20
# 4        옆에(211.204)  깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라 2001-07-17 19:19:57
# ...              ...                              ...                 ...
# 21644             ㅇㅇ                              23년 2023-01-01 21:53:18
# 21645             ㅇㅇ                    제발 여친생기게 해주세요 2023-01-07 17:13:44
# 21646     ㅇㅇ(223.39)                        로리보지따묵고싶노 2023-01-07 22:50:23
# 21647            하스트                               섹스 2023-01-13 03:26:59
# 21648     ㅇㅇ(223.62)               성지순례왔습니다 학원 안가고싶어요 2023-01-17 23:21:16
#
# [21649 rows x 3 columns]

# %%
# df['ymdtime'] = pd.to_datetime(df['날짜'], format='%Y.%m.%d %H:%M:%S', errors='raise')
df['date'] = df['날짜'].dt.date
df['year'] = df['날짜'].dt.year
df['month'] = df['날짜'].dt.month
df
# Out:
#                  닉네임                               댓글                  날짜  \
# 0      복숭아맛(163.180)               아참 운송료 미포함 가격 입니다. 2001-07-17 17:55:57
# 1         정추영(61.78)                         재미없스.... 2001-07-17 18:03:12
# 2         x(211.206)       야~ 참 재밋스신 분이시네요...한참 웃엇습니다 2001-07-17 18:13:45
# 3       ㅡ.ㅡ(211.107)          >>ㅑ~~~~~~~ 안사안사~~~~~~~~ 2001-07-17 18:57:20
# 4        옆에(211.204)  깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라 2001-07-17 19:19:57
# ...              ...                              ...                 ...
# 21644             ㅇㅇ                              23년 2023-01-01 21:53:18
# 21645             ㅇㅇ                    제발 여친생기게 해주세요 2023-01-07 17:13:44
# 21646     ㅇㅇ(223.39)                        로리보지따묵고싶노 2023-01-07 22:50:23
# 21647            하스트                               섹스 2023-01-13 03:26:59
# 21648     ㅇㅇ(223.62)               성지순례왔습니다 학원 안가고싶어요 2023-01-17 23:21:16
#
#              date  year  month
# 0      2001-07-17  2001      7
# ...

# %%
dfy = pd.DataFrame(df['year'].value_counts(sort=False))
dfy
# Out:
#       year
# 2001  3480
# 2002  3828
# 2003  5433
# 2004  2440
# 2005   688
# 2006    26
# 2007   421
# 2008  1103
# 2009   428
# 2010   403
# 2011   278
# 2012   155
# 2013   261
# 2014   296
# 2015   225
# 2016   923
# 2017    93
# 2018   207
# 2019   493
# 2020   216
# 2021   156
# 2022    91
# 2023     5

# %%
dfy2009up = df[df['year'] >= 2009]
dfy2009up
# Out:
#                닉네임                                                 댓글  \
# 17419  뭐야(121.184)                             왜 1월1일 됐는데 아직 31일이냐 ㅠㅠ
# 17420       #NAME?                             새해 기념 성지 순례.. 새해복 많이!!
# 17421  ..(118.219)  ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성...
# 17422  ㅇㅇ(222.236)                                     이게 디시가 유명해진 계기
# 17423       TYNANT   원조성지 새해 첫 방문 2009년 기축년 새해 바라는일 모두 이뤄지길 진심으로 바랍니다
# ...            ...                                                ...
# 21644           ㅇㅇ                                                23년
# 21645           ㅇㅇ                                      제발 여친생기게 해주세요
# 21646   ㅇㅇ(223.39)                                          로리보지따묵고싶노
# 21647          하스트                                                 섹스
# 21648   ㅇㅇ(223.62)                                 성지순례왔습니다 학원 안가고싶어요
#
#                        날짜        date  year  month
# 17419 2009-01-01 00:08:19  2009-01-01  2009      1
# ...

# %%
slist = ['성지순례', '해주세요', '로또', '섹스', '사랑']
sw = '|'.join(slist)

# %%
dfy2009up = dfy2009up.dropna()

# %%
dfy9up = dfy2009up[dfy2009up['댓글'].str.contains(sw)]
dfy9up
# Out:
#                   닉네임                                                 댓글  \
# 17421     ..(118.219)  ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성...
# 17425   매로고침(222.234)  성지순례●█▀█▄ 성지순례●█▀█▄ 성지순례●█▀█▄ 성지순례●█▀█▄ 성지순례●█...
# 17428    박보영(125.184)  ●█▀█▄●█▀█▄●█▀█▄●█▀█▄ 키5cm만더자라게해주세요●█▀█▄●█▀█▄●█...
# 17429  성지순례를!(220.92)  ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성...
# 17430  성지순례를!(220.92)  ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성지순례 ●█▀█▄성...
# ...               ...                                                ...
# 21642     ㅇㅇ(117.111)  최초의 성지에 순례왔습니다. 이번에 친 jlpt n2급 최소 93점 이상 나와서 과...
# 21643      ㅇㅇ(116.39)                                               성지순례
# 21645              ㅇㅇ                                      제발 여친생기게 해주세요
# 21647             하스트                                                 섹스
# 21648      ㅇㅇ(223.62)                                 성지순례왔습니다 학원 안가고싶어요
#
#                        날짜        date  year  month
# ...

# %%
df2019 = df

# %%
dfy9up1 = pd.DataFrame(dfy9up['year'].value_counts(sort=False))
res1 = pd.concat([dfy, dfy9up1], axis=1)
res1
# Out:
#       year   year
# 2001  3480    NaN
# 2002  3828    NaN
# 2003  5433    NaN
# 2004  2440    NaN
# 2005   688    NaN
# 2006    26    NaN
# 2007   421    NaN
# 2008  1103    NaN
# 2009   428  201.0
# 2010   403  207.0
# 2011   278  122.0
# 2012   155   65.0
# 2013   261  157.0
# 2014   296  175.0
# 2015   225  151.0
# 2016   923   82.0
# 2017    93   45.0
# 2018   207  103.0
# 2019   493   40.0
# 2020   216   91.0
# 2021   156   68.0
# 2022    91   39.0
# 2023     5    3.0

# %%
df.rename(columns={'닉네임':'작성자'}, inplace=True)
df = df[['작성자', '댓글', 'date', 'year']]
df
# Out:
#                  작성자                               댓글        date  year
# 0      복숭아맛(163.180)               아참 운송료 미포함 가격 입니다.  2001-07-17  2001
# 1         정추영(61.78)                         재미없스....  2001-07-17  2001
# 2         x(211.206)       야~ 참 재밋스신 분이시네요...한참 웃엇습니다  2001-07-17  2001
# 3       ㅡ.ㅡ(211.107)          >>ㅑ~~~~~~~ 안사안사~~~~~~~~  2001-07-17  2001
# 4        옆에(211.204)  깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라  2001-07-17  2001
# ...              ...                              ...         ...   ...
# 21644             ㅇㅇ                              23년  2023-01-01  2023
# 21645             ㅇㅇ                    제발 여친생기게 해주세요  2023-01-07  2023
# 21646     ㅇㅇ(223.39)                        로리보지따묵고싶노  2023-01-07  2023
# 21647            하스트                               섹스  2023-01-13  2023
# 21648     ㅇㅇ(223.62)               성지순례왔습니다 학원 안가고싶어요  2023-01-17  2023
#
# [21649 rows x 4 columns]

# %%
# 닉네임에 있는 '#NAME?' 값이 nan 값인지 확인하고자 특정 기간 데이터 검토
df_na=df[(df['날짜']>='2002-11-14')&(df['날짜']<='2002-11-15')]
df_na

# %%
df[df['댓글'].isnull()]

# %%
df = df.dropna(how = 'any')
df
# Out:
#                  닉네임                               댓글                  날짜
# 0      복숭아맛(163.180)               아참 운송료 미포함 가격 입니다. 2001-07-17 17:55:57
# 1         정추영(61.78)                         재미없스.... 2001-07-17 18:03:12
# 2         x(211.206)       야~ 참 재밋스신 분이시네요...한참 웃엇습니다 2001-07-17 18:13:45
# 3       ㅡ.ㅡ(211.107)          >>ㅑ~~~~~~~ 안사안사~~~~~~~~ 2001-07-17 18:57:20
# 4        옆에(211.204)  깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라 2001-07-17 19:19:57
# ...              ...                              ...                 ...
# 21644             ㅇㅇ                              23년 2023-01-01 21:53:18
# 21645             ㅇㅇ                    제발 여친생기게 해주세요 2023-01-07 17:13:44
# 21646     ㅇㅇ(223.39)                        로리보지따묵고싶노 2023-01-07 22:50:23
# 21647            하스트                               섹스 2023-01-13 03:26:59
# 21648     ㅇㅇ(223.62)               성지순례왔습니다 학원 안가고싶어요 2023-01-17 23:21:16
#
# [21626 rows x 3 columns]

# %%
dfy = pd.DataFrame(df['year'].value_counts(sort=False))
dfy
# Out:
#       year
# 2001  3480
# 2002  3828
# 2003  5433
# 2004  2440
# 2005   688
# 2006    26
# 2007   421
# 2008  1103
# 2009   428
# 2010   403
# 2011   278
# 2012   155
# 2013   261
# 2014   296
# 2015   225
# 2016   923
# 2017    93
# 2018   207
# 2019   493
# 2020   216
# 2021   156
# 2022    91
# 2023     5

# %%
# !pip install plotnine

# %%
from plotnine import *

# %%
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = '/content/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# %%
import matplotlib as mpl
mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumBarunGothic')

# %%
#  + geom_bar(fill='#27a287')

# %%
(ggplot(df)
 + aes('year')
 + geom_bar(fill='black')
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (8781191105476)>

# %%
(ggplot(df)
 + aes('month')
 + geom_bar(fill='skyblue')
 + scale_x_continuous(breaks = seq(1, 12, 1))
#  + ggtitle('monthly reply number')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-46170eea339a> in <module>
#       2  + aes('month')
#       3  + geom_bar(fill='skyblue')
# ----> 4  + scale_x_continuous(breaks = seq(1, 12, 1))
#       5 #  + ggtitle('monthly reply number')
#       6  + theme(text=element_text(family='NanumBarunGothic'))
#
# NameError: name 'seq' is not defined

# %%
(ggplot(df)
 + aes('date')
 + geom_bar(fill='#27a287')
 + scale_x_date(breaks = '2 year')
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (8741429390017)>

# %%
df['합검토']=df['작성자']+" "+df['댓글']
df
# Out:
# <ipython-input-16-9b12fcb0b83c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  작성자                               댓글        date  year  \
# 0      복숭아맛(163.180)               아참 운송료 미포함 가격 입니다.  2001-07-17  2001
# 1         정추영(61.78)                         재미없스....  2001-07-17  2001
# 2         x(211.206)       야~ 참 재밋스신 분이시네요...한참 웃엇습니다  2001-07-17  2001
# 3       ㅡ.ㅡ(211.107)          >>ㅑ~~~~~~~ 안사안사~~~~~~~~  2001-07-17  2001
# 4        옆에(211.204)  깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라  2001-07-17  2001
# ...              ...                              ...         ...   ...
# 21644             ㅇㅇ                              23년  2023-01-01  2023
# 21645             ㅇㅇ                    제발 여친생기게 해주세요  2023-01-07  2023
# ...

# %%
df1 = df['합검토'].drop_duplicates()
df1.to_csv('/content/drive/MyDrive/Colab Notebooks/쿠키닷컴/cd_check.csv', encoding='utf-8-sig')

# %%
df1
# Out:
# 0                   복숭아맛(163.180) 아참 운송료 미포함 가격 입니다.
# 1                                정추영(61.78) 재미없스....
# 2              x(211.206) 야~ 참 재밋스신 분이시네요...한참 웃엇습니다
# 3               ㅡ.ㅡ(211.107) >>ㅑ~~~~~~~ 안사안사~~~~~~~~
# 4        옆에(211.204) 깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라
#                             ...
# 21644                                         ㅇㅇ 23년
# 21645                               ㅇㅇ 제발 여친생기게 해주세요
# 21646                           ㅇㅇ(223.39) 로리보지따묵고싶노
# 21647                                         하스트 섹스
# 21648                  ㅇㅇ(223.62) 성지순례왔습니다 학원 안가고싶어요
# Name: 합검토, Length: 20031, dtype: object

# %%
plt.figure(figsize=(12,6))
df['year'].value_counts().sort_index().plot.bar()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df.sort_values('year'), palette='Spectral', x='year')

# %%
dfdore = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/쿠키닷컴/성지순례_도배제거.csv", encoding="utf-8", parse_dates=['날짜'])
dfdore['date'] = dfdore['날짜'].dt.date
dfdore['year'] = dfdore['날짜'].dt.year
dfdore['month'] = dfdore['날짜'].dt.month
dfdore['합검토']=dfdore['작성자']+" "+dfdore['댓글']
dfdore
# Out:
#                  작성자                               댓글                  날짜  \
# 0      복숭아맛(163.180)               아참 운송료 미포함 가격 입니다. 2001-07-17 17:55:57
# 1         정추영(61.78)                         재미없스.... 2001-07-17 18:03:12
# 2         x(211.206)       야~ 참 재밋스신 분이시네요...한참 웃엇습니다 2001-07-17 18:13:45
# 3       ㅡ.ㅡ(211.107)          >>ㅑ~~~~~~~ 안사안사~~~~~~~~ 2001-07-17 18:57:20
# 4        옆에(211.204)  깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라 2001-07-17 19:19:57
# ...              ...                              ...                 ...
# 19411             ㅇㅇ                              23년 2023-01-01 21:53:18
# 19412             ㅇㅇ                    제발 여친생기게 해주세요 2023-01-07 17:13:44
# 19413     ㅇㅇ(223.39)                        로리보지따묵고싶노 2023-01-07 22:50:23
# 19414            하스트                               섹스 2023-01-13 03:26:59
# 19415     ㅇㅇ(223.62)               성지순례왔습니다 학원 안가고싶어요 2023-01-17 23:21:16
#
#              date  year  month                                          합검토
# ...

# %%
dfdore = dfdore[['date', '합검토']]
dfdore
# Out:
#              date                                          합검토
# 0      2001-07-17             복숭아맛(163.180) 아참 운송료 미포함 가격 입니다.
# 1      2001-07-17                          정추영(61.78) 재미없스....
# 2      2001-07-17        x(211.206) 야~ 참 재밋스신 분이시네요...한참 웃엇습니다
# 3      2001-07-17         ㅡ.ㅡ(211.107) >>ㅑ~~~~~~~ 안사안사~~~~~~~~
# 4      2001-07-17  옆에(211.204) 깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라
# ...           ...                                          ...
# 19411  2023-01-01                                       ㅇㅇ 23년
# 19412  2023-01-07                             ㅇㅇ 제발 여친생기게 해주세요
# 19413  2023-01-07                         ㅇㅇ(223.39) 로리보지따묵고싶노
# 19414  2023-01-13                                       하스트 섹스
# 19415  2023-01-17                ㅇㅇ(223.62) 성지순례왔습니다 학원 안가고싶어요
#
# [19416 rows x 2 columns]

# %%
dfdore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19410 entries, 0 to 19409
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    19410 non-null  object
#  1   합검토     19405 non-null  object
# dtypes: object(2)
# memory usage: 303.4+ KB

# %%
dfdore = dfdore.drop_duplicates()

# %%
dfdore['date'] = pd.to_datetime(dfdore['date'], format='%Y-%m-%d', errors='raise')
dfdore
# Out:
# <ipython-input-25-22cb814bf0c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             date                                          합검토
# 0     2001-07-17             복숭아맛(163.180) 아참 운송료 미포함 가격 입니다.
# 1     2001-07-17                          정추영(61.78) 재미없스....
# 2     2001-07-17        x(211.206) 야~ 참 재밋스신 분이시네요...한참 웃엇습니다
# 3     2001-07-17         ㅡ.ㅡ(211.107) >>ㅑ~~~~~~~ 안사안사~~~~~~~~
# 4     2001-07-17  옆에(211.204) 깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라
# ...          ...                                          ...
# 19411 2023-01-01                                       ㅇㅇ 23년
# 19412 2023-01-07                             ㅇㅇ 제발 여친생기게 해주세요
# 19413 2023-01-07                         ㅇㅇ(223.39) 로리보지따묵고싶노
# ...

# %%
dfdore['year'] = dfdore['date'].dt.year
# Out:
# <ipython-input-26-a4d74d521877>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dfdore
# Out:
#             date                                          합검토  year
# 0     2001-07-17             복숭아맛(163.180) 아참 운송료 미포함 가격 입니다.  2001
# 1     2001-07-17                          정추영(61.78) 재미없스....  2001
# 2     2001-07-17        x(211.206) 야~ 참 재밋스신 분이시네요...한참 웃엇습니다  2001
# 3     2001-07-17         ㅡ.ㅡ(211.107) >>ㅑ~~~~~~~ 안사안사~~~~~~~~  2001
# 4     2001-07-17  옆에(211.204) 깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라  2001
# ...          ...                                          ...   ...
# 19411 2023-01-01                                       ㅇㅇ 23년  2023
# 19412 2023-01-07                             ㅇㅇ 제발 여친생기게 해주세요  2023
# 19413 2023-01-07                         ㅇㅇ(223.39) 로리보지따묵고싶노  2023
# 19414 2023-01-13                                       하스트 섹스  2023
# 19415 2023-01-17                ㅇㅇ(223.62) 성지순례왔습니다 학원 안가고싶어요  2023
#
# [19394 rows x 3 columns]

# %%
dfdore['year'].value_counts(sort=False)
# Out:
# 2001    3378
# 2002    3785
# 2003    5306
# 2004    2435
# 2005     684
# 2006      26
# 2007     386
# 2008     803
# 2009     354
# 2010     299
# 2011     200
# 2012     109
# 2013     235
# 2014     264
# 2015     216
# 2016     170
# 2017      78
# 2018     176
# 2019      81
# 2020     173
# 2021     142
# 2022      89
# 2023       5
# Name: year, dtype: int64

# %%
dfdorey = pd.DataFrame(dfdore['year'].value_counts(sort=False))
dfdorey.to_csv('/content/drive/MyDrive/Colab Notebooks/쿠키닷컴/cd_yearly.csv', encoding='utf-8-sig')

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=dfdore.sort_values('year'), palette='Spectral', x='year')

# %%
(ggplot(dfdore)
 + aes('year')
 + geom_bar(fill='black')
 + theme(text=element_text(family='NanumBarunGothic'),
        axis_text_x=element_text(rotation=60))
)
# Out:
# <ggplot: (8778939486648)>

# %%
dfdore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19410 entries, 0 to 19409
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    19410 non-null  datetime64[ns]
#  1   합검토     19405 non-null  object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 303.4+ KB

# %%
dfdore = dfdore.dropna()

# %%
dfdore.to_csv("/content/drive/MyDrive/Colab Notebooks/쿠키닷컴/coopp.csv", index=False, encoding='utf-8-sig')

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df.sort_values('date'), palette='Spectral', x='date')

# %%
df1 = df[['year', 'month', 'date', '댓글', '닉네임']]
df1
# Out:
#        year  month        date  \
# 0      2001      7  2001-07-17
# 1      2001      7  2001-07-17
# 2      2001      7  2001-07-17
# 3      2001      7  2001-07-17
# 4      2001      7  2001-07-17
# ...     ...    ...         ...
# 21642  2022     12  2022-12-05
# 21643  2022     12  2022-12-25
# 21644  2023      1  2023-01-01
# 21645  2023      1  2023-01-07
# 21646  2023      1  2023-01-07
#
#                                                       댓글            닉네임
# 0                                     아참 운송료 미포함 가격 입니다.  복숭아맛(163.180)
# 1                                               재미없스....     정추영(61.78)
# 2                             야~ 참 재밋스신 분이시네요...한참 웃엇습니다     x(211.206)
# 3                                >>ㅑ~~~~~~~ 안사안사~~~~~~~~   ㅡ.ㅡ(211.107)
# 4                        깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라    옆에(211.204)
# ...                                                  ...            ...
# 21642  최초의 성지에 순례왔습니다. 이번에 친 jlpt n2급 최소 93점 이상 나와서 과...    ㅇㅇ(117.111)
# ...

# %%
df1sp1 = df1[df1['댓글'].str.contains('성지', na=False)]
df1sp1
# Out:
#        year  month        date  \
# 962    2001      7  2001-07-31
# 4816   2002      7  2002-07-25
# 5084   2002      8  2002-08-07
# 5504   2002      8  2002-08-31
# 5514   2002      9  2002-09-01
# ...     ...    ...         ...
# 21632  2022     10  2022-10-18
# 21636  2022     11  2022-11-03
# 21641  2022     11  2022-11-25
# 21642  2022     12  2022-12-05
# 21643  2022     12  2022-12-25
#
#                                                       댓글                닉네임
# 962     프링글스 껍데기 필통으로 만든것과 어떻게 교환 안될까요?실리콘 합성지라 방수도 됩니다.        교환(211.207)
# 4816                                     수많은 햏자들의 성지라오..        햏자(211.195)
# 5084           성지 순례 하고 갑니다. Ah~ Ye~ (2002-08-07) am9:10       ㅋㅋㅋ(210.216)
# 5504                      성지 비슷하게 되어버린 곳에 오게되니 기쁘구료 기념이오    그사람이좋다(211.179)
# 5514          이게 쿠키닷컴의 신화구냥.... 디씨 최고의 성지를 방문한 소감이 새롭쿠나.  2002.9.1(211.191)
# ...                                                  ...                ...
# ...

# %%
df1sp2 = df1[df1['댓글'].str.contains('성지순례', na=False)]
df1sp2
# Out:
#        year  month        date  \
# 6034   2002      9  2002-09-23
# 6596   2002     10  2002-10-31
# 6644   2002     11  2002-11-01
# 6650   2002     11  2002-11-02
# 6697   2002     11  2002-11-04
# ...     ...    ...         ...
# 21631  2022     10  2022-10-15
# 21632  2022     10  2022-10-18
# 21636  2022     11  2022-11-03
# 21641  2022     11  2022-11-25
# 21643  2022     12  2022-12-25
#
#                                                       댓글             닉네임
# 6034                                 아햏햏..초보햏자요..성지순례중이오      어뜸(66.183)
# 6596                           구마적양의 리플 1060개째 쌔우고 성지순례.    ...(211.183)
# 6644                           성지순례 다녀감... 창호 여기 왔다가다...       창호(61.72)
# 6650                      신화요...영원하기를...정말 성지순례온기분이구려...  이건...(218.232)
# 6697                             나도 쎄웠소..T_T..성지순례단이오...   아아..(211.207)
# ...                                                  ...             ...
# ...

# %%
d1p1 = pd.crosstab(df1sp1, df1sp2)
d1p1[["성지", "성지순례"]].plot.bar(rot=0)

# %%
df1sp1['year'].value_counts(sort=False)
# Out:
# 2001      1
# 2002     25
# 2003    458
# 2004    663
# 2005    244
# 2006     16
# 2007    214
# 2008    531
# 2009    123
# 2010     85
# 2011     40
# 2012     24
# 2013     72
# 2014    108
# 2015    126
# 2016     58
# 2017     30
# 2018     38
# 2019     24
# 2020     50
# 2021     45
# 2022     18
# Name: year, dtype: int64

# %%
df1sp2['year'].value_counts(sort=False)

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df1sp1.sort_values('year'), x='year')

# %%
dfdore
# Out:
#             date                                                합검토  year
# 0     2001-07-17                   복숭아맛(163.180) 아참 운송료 미포함 가격 입니다.  2001
# 1     2001-07-17                                정추영(61.78) 재미없스....  2001
# 2     2001-07-17              x(211.206) 야~ 참 재밋스신 분이시네요...한참 웃엇습니다  2001
# 3     2001-07-17               ㅡ.ㅡ(211.107) >>ㅑ~~~~~~~ 안사안사~~~~~~~~  2001
# 4     2001-07-17        옆에(211.204) 깔삼하게 그대로 찍지 고것도 뜯어먹고 찍었네.. 가여워라  2001
# ...          ...                                                ...   ...
# 19405 2022-11-14                                      ㅇㅇ(121.190) 헉  2022
# 19406 2022-11-22                                  ParticleEffe.. 색스  2022
# 19407 2022-11-22  ㅇㅇ(220.118) ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ...  2022
# 19408 2022-11-25                               ㅇㅇ(125.179) 성지순례왔습니다  2022
# 19409 2022-12-05  ㅇㅇ(117.111) 최초의 성지에 순례왔습니다. 이번에 친 jlpt n2급 최소 ...  2022
#
# [19388 rows x 3 columns]

# %%
dfdore_hp = dfdore[dfdore['합검토'].str.contains('성지', na=False)]
dfdore_hp
# Out:
#             date                                                합검토  year
# 940   2001-07-31  교환(211.207) 프링글스 껍데기 필통으로 만든것과 어떻게 교환 안될까요?실리콘...  2001
# 4716  2002-07-25                        햏자(211.195) 수많은 햏자들의 성지라오..  2002
# 4978  2002-08-07  ㅋㅋㅋ(210.216) 성지 순례 하고 갑니다. Ah~ Ye~ (2002-08-07...  2002
# 5398  2002-08-31     그사람이좋다(211.179) 성지 비슷하게 되어버린 곳에 오게되니 기쁘구료 기념이오  2002
# 5408  2002-09-01  2002.9.1(211.191) 이게 쿠키닷컴의 신화구냥.... 디씨 최고의 성지를...  2002
# ...          ...                                                ...   ...
# 19398 2022-10-15  엄브라푿즈 안녕하세요 성지순례옵니다제 인생 첫 성지순례인데이번 2학기 중간수학,언매...  2022
# 19399 2022-10-18          ㅇㅇ(202.137) 성지순례왔습니다제인생 단 한번이라도 ㅅㅅ하게 해주세요  2022
# 19403 2022-11-03                                       Q84 성지순례왓습니다  2022
# 19408 2022-11-25                               ㅇㅇ(125.179) 성지순례왔습니다  2022
# 19409 2022-12-05  ㅇㅇ(117.111) 최초의 성지에 순례왔습니다. 이번에 친 jlpt n2급 최소 ...  2022
#
# [2948 rows x 3 columns]

# %%
# 940 행의 '성지'는 '합성지'이므로 삭제
dfdore_hp = dfdore_hp.drop([940])
dfdore_hp
# Out:
#             date                                                합검토  year
# 4716  2002-07-25                        햏자(211.195) 수많은 햏자들의 성지라오..  2002
# 4978  2002-08-07  ㅋㅋㅋ(210.216) 성지 순례 하고 갑니다. Ah~ Ye~ (2002-08-07...  2002
# 5398  2002-08-31     그사람이좋다(211.179) 성지 비슷하게 되어버린 곳에 오게되니 기쁘구료 기념이오  2002
# 5408  2002-09-01  2002.9.1(211.191) 이게 쿠키닷컴의 신화구냥.... 디씨 최고의 성지를...  2002
# 5690  2002-09-13             아=햏²(61.78) 드디어 다시 성지에 도달했쏘만...쌔워질까...  2002
# ...          ...                                                ...   ...
# 19398 2022-10-15  엄브라푿즈 안녕하세요 성지순례옵니다제 인생 첫 성지순례인데이번 2학기 중간수학,언매...  2022
# 19399 2022-10-18          ㅇㅇ(202.137) 성지순례왔습니다제인생 단 한번이라도 ㅅㅅ하게 해주세요  2022
# 19403 2022-11-03                                       Q84 성지순례왓습니다  2022
# 19408 2022-11-25                               ㅇㅇ(125.179) 성지순례왔습니다  2022
# 19409 2022-12-05  ㅇㅇ(117.111) 최초의 성지에 순례왔습니다. 이번에 친 jlpt n2급 최소 ...  2022
#
# [2947 rows x 3 columns]

# %%
dfdf = dfdore_hp[dfdore_hp['합검토'].str.contanins('성지니'), na=False]
dfdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-62c5deb8d488> in <module>
# ----> 1 dfdore_hp[dfdore_hp['합검토'].str.contanins('성지니')]
#
# AttributeError: 'StringMethods' object has no attribute 'contanins'

# %%
dfdore_hp['year'].value_counts(sort=False)
# Out:
# 2001      1
# 2002     30
# 2003    494
# 2004    697
# 2005    257
# 2006     17
# 2007    209
# 2008    402
# 2009    117
# 2010     90
# 2011     35
# 2012     24
# 2013     76
# 2014    111
# 2015    127
# 2016     59
# 2017     30
# 2018     38
# 2019     23
# 2020     50
# 2021     44
# 2022     17
# Name: year, dtype: int64
